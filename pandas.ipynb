# %% [markdown]
# * Rahil Sayyad
# * Email id: rahilsayyad389@gmail.com

# %% [markdown]
# **import libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## read data

# %%
Rs=pd.read_csv("C:\\Users\\Rahil\\Desktop\\Data Science\\USA_Housing.csv")

# %%
Rs
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
Rs.head(10) #show upper 10 values
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
Rs.tail(7) #show lower 10 values
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4993      69639.140896             5.007510                   7.778375
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4993                          6.05     54056.128430  1.381831e+06
# 4994                          4.16     22695.695480  9.053549e+05
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# ...

# %%
s={"A":[1,2,3,4],"B":[2,3,4,5],"C":[5,6,7,8],"D":[1,3,5,7]} # create a dictinary
pd.DataFrame(s) # create a DataFrame
# Out:
#    A  B  C  D
# 0  1  2  5  1
# 1  2  3  6  3
# 2  3  4  7  5
# 3  4  5  8  7

# %%
from numpy.random import randn

# %%
Rs.to_csv("data") # to save a data in laptop folder

# %%
Sim=pd.DataFrame(randn(4,5),index='A B C D'.split(),columns='E F G H I'.split())  # create a DataFrame

# %%
Sim
# Out:
#           E         F         G         H         I
# A  0.428150 -1.520308 -0.521302  0.401227  0.329394
# B -1.464486 -0.062775 -0.499187 -0.320087  1.019818
# C  0.707974  0.460239  0.596650 -2.035695  0.468868
# D -0.455005 -0.686143  0.904367  0.435929 -0.787312

# %%
Sim['E'] # access a column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29916\3037408326.py in <module>
# ----> 1 Sim['E'] # access a column
#
# NameError: name 'Sim' is not defined

# %%
Sim[['E','G','I']] # provide a list to access multiple column
# Out:
#           E         G         I
# A -0.125649 -0.144551  1.116724
# B  0.074752 -0.435614 -1.515542
# C  1.671259  1.731266  1.157181
# D -0.266497  1.164033  0.053744

# %%
Sim['J']=Sim['E']+Sim['I'] # create a new column

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.125649  0.418223 -0.144551  1.323070  1.116724  0.991076
# B  0.074752  0.727201 -0.435614  3.067661 -1.515542 -1.440790
# C  1.671259  0.978042  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  0.666773  1.164033  2.017453  0.053744 -0.212753

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.125649  0.418223 -0.144551  1.323070  1.116724  0.991076
# B  0.074752  0.727201 -0.435614  3.067661 -1.515542 -1.440790
# C  1.671259  0.978042  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  0.666773  1.164033  2.017453  0.053744 -0.212753

# %%
Sim.drop('A',axis=0) # drop a column temporary
# Out:
#           E         F         G         H         I         J
# B  0.074752  0.727201 -0.435614  3.067661 -1.515542 -1.440790
# C  1.671259  0.978042  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  0.666773  1.164033  2.017453  0.053744 -0.212753

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.125649  0.418223 -0.144551  1.323070  1.116724  0.991076
# B  0.074752  0.727201 -0.435614  3.067661 -1.515542 -1.440790
# C  1.671259  0.978042  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  0.666773  1.164033  2.017453  0.053744 -0.212753

# %%
Sim.drop('B',axis=0,inplace=True) # drop a column permenantly

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.125649  0.418223 -0.144551  1.323070  1.116724  0.991076
# C  1.671259  0.978042  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  0.666773  1.164033  2.017453  0.053744 -0.212753

# %%
Sim.drop('F',axis=1)
# Out:
#           E         G         H         I         J
# A -0.125649 -0.144551  1.323070  1.116724  0.991076
# C  1.671259  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  1.164033  2.017453  0.053744 -0.212753

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.125649  0.418223 -0.144551  1.323070  1.116724  0.991076
# C  1.671259  0.978042  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  0.666773  1.164033  2.017453  0.053744 -0.212753

# %%
Sim.iloc[1:,4:] # access using index no(row,col)
# Out:
#           I         J
# C  1.157181  2.828440
# D  0.053744 -0.212753

# %%
Sim.iloc[0:2,0:2] # access using index no(row,col)
# Out:
#           E         F
# A -0.288840  1.273322
# C  0.597549 -1.157802

# %%
Sim.iloc[0:2,3:5] # access using index no(row,col)
# Out:
#           H         I
# A  1.323070  1.116724
# C -0.544719  1.157181

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.125649  0.418223 -0.144551  1.323070  1.116724  0.991076
# C  1.671259  0.978042  1.731266 -0.544719  1.157181  2.828440
# D -0.266497  0.666773  1.164033  2.017453  0.053744 -0.212753

# %%
Sim['E']
# Out:
# A   -0.125649
# C    1.671259
# D   -0.266497
# Name: E, dtype: float64

# %%
Sim.iloc[1]
# Out:
# E    0.597549
# F   -1.157802
# G    1.878052
# H   -1.115693
# I   -0.973857
# J   -0.376308
# Name: C, dtype: float64

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.288840  1.273322 -0.630765 -1.344453  1.138037  0.849197
# C  0.597549 -1.157802  1.878052 -1.115693 -0.973857 -0.376308
# D -0.818112 -0.335133 -0.900335 -0.239355 -0.114873 -0.932985

# %%
Sim.loc['A','H'] # access using label (rows)
# Out:
# -1.3444525424000424

# %%
Sim
# Out:
#           E         F         G         H         I         J
# A -0.288840  1.273322 -0.630765 -1.344453  1.138037  0.849197
# C  0.597549 -1.157802  1.878052 -1.115693 -0.973857 -0.376308
# D -0.818112 -0.335133 -0.900335 -0.239355 -0.114873 -0.932985

# %% [markdown]
# ## condition wise selection

# %%
Sim[Sim>0]
# Out:
#           E         F         G   H         I         J
# A       NaN  1.273322       NaN NaN  1.138037  0.849197
# C  0.597549       NaN  1.878052 NaN       NaN       NaN
# D       NaN       NaN       NaN NaN       NaN       NaN

# %%
Sim>0
# Out:
#        E      F      G      H      I      J
# A  False   True  False  False   True   True
# C   True  False   True  False  False  False
# D  False  False  False  False  False  False

# %%
Sim[Sim['E']>0]
# Out:
#           E         F         G         H         I         J
# C  0.597549 -1.157802  1.878052 -1.115693 -0.973857 -0.376308

# %%
Sim[Sim['E']>0]['I']
# Out:
# C   -0.973857
# Name: I, dtype: float64

# %%
Sim[Sim['E']>0][['I','J']]
# Out:
#           I         J
# C -0.973857 -0.376308

# %%
Sim[(Sim['F']>0) & (Sim['I'] > 0)]
# Out:
#          E         F         G         H         I         J
# A -0.28884  1.273322 -0.630765 -1.344453  1.138037  0.849197
